# %% [markdown]
# # Der neue Job
# Du hast gerade deine neue Stelle bei der Polizei angetreten und
# wegen der guten Kontakte deines Onkels bist du auch bei der Drogenfahndung
# gelandet, wo ja auch unbedingt hin wolltest.
#
# „Willkommen bei uns!“ begrüßt dich einer der neuen Kollegen - etwa 10 Jahre
# älter als du, gutaussehend, ...
# „Wir haben gehört, dass du ein Computerprofi bist? Super! Wir haben hier nämlich
# ein kleines großes Problem, bei dem du uns unbedingt helfen musst!
#
# Unsere IT-Forensik ist absolut überlastet und wir konnten gestern einen Laptop
# sicherstellen. Einem Kollegen ist es auch gelungen, das verschlüsselte Kennwort
# auszulesen, aber jetzt sind wir mit unserem Latein am Ende!
#
# > Kennwort-Hash: f4f4dd5d0aa5923102980e698dfdaaa2b429277505f0ff53255db853669a7d72
#
# Du hast doch in solchen Dingen Erfahrung, oder? Wir müssen diese Kiste unbedingt
# knacken! Schau mal, was du machen kannst, ok?

# %% [markdown]
# ## Hohe Erwartungen
# Ja - du hast die Klappe in der Kantine zu weit aufgerissen und schon
# bekommst du die Rechnung ... „Du hast doch Erahrung ...“ - von wegen!
# Aber jetzt musst du da durch - komme was wolle!
#
# <div style="background-color:#e8f0fe; padding:10px; border-radius:8px;">
# <strong>So ein Mist!!!!</strong>
# </div>

# %% [markdown]
# Du beschließt, den einfachsten Weg zu probieren und eine Wörterbuch-Attacke
# auf das verschlüsselte Kennwort zu probieren. Vielleicht war der Benutzer ja
# unvorsichtig bei der Wahl seines Kennworts? Doch dafür brauchst du ein Wörterbuch!
# Du erinnerst sich zwar nicht mehr an die Internetseite, aber eine kleine Recherche
# liefert die gewünschte Adresse!

# %%
# Hier einfach rein klicken und dann "strg + enter"

import hashlib
import urllib.request
from urllib.request import urlretrieve

url = "https://raw.githubusercontent.com/danielmiessler/SecLists/refs/heads/master/Passwords/darkc0de.txt"

urlretrieve(url, "woerterbuch.txt")

# %% [markdown]
# Gut - das sind nun ein paar Wörter zum abchecken. Wie machst du weiter?
#
# * Datei lesen
# * Schleife über die Wörter
# * Jedes Wort verschlüsseln und mit dem Hash vergleichen
#
# Sieht übersichtlich aus ....

# %%
# Finde heraus, wie man alle Zeilen (das sind hier die Wörter)
# einer Datei in eine Liste lesen kann. Nenne die Liste "zeilen".

# %% [markdown]
# Gut. In der Liste `zeilen` stehen nun alle Wörter aus dem Wörterbuch.
# Wie viele das wohl aktuell sind?

# %%
# Finde heraus, wie man sich die Länge einer Liste ausgeben lassen kann.

# %% [markdown]
# Wow ... mehr als gedacht!
# So nun musst du dich um das Verschlüsseln kümmern.
# Wie ging das nochmal? Du schaust in deinen Spickzettel.
#
# <div style="background-color:#e8f0fe; padding:10px; border-radius:8px;">
# <strong>HINWEIS!!!!</strong><br>
#     <p>Diese Verschlüsselungsmethode wird real nicht verwendet - wir sind also auf der
#     sicheren Seite in Bezug auf den "Hacker-Paragraphen" § 202c. Dies trifft insbesondere
#     zu, da keine spezialisierten Tools wie z.B. HashCat zum Einsatz kommen!</p>
# </div>

# %%
# Binde das passende Modul ein

# Trage in die Variable *hash* das verschlüsselte Kennwort aus der Angabe ein.
hash = b" ............ "

# Erstelle eine Schleife über alle Zeilen

# Verschlüssle die aktuelle Zeile und vergleiche das Ergebnis mit "hash"

# Gib eine Erfolgsmeldung aus, wenn das Kennwort gefunden wurde
